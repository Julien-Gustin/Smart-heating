# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from functools import reduce

# %% [markdown]
# # Import data

# %%
data = pd.read_csv(os.path.join("data", "data.csv"), delimiter=";")

# %%
figsize = (30, 15)

# %%
def plot_data(data: pd.DataFrame, x: str, y):
    ax = data.plot(figsize=figsize, x=x, y=y)
    ax.set_xlabel(x)
    ax.set_ylabel("Temperature")

# %%
data.head()
# Out:
#                     Datetime  T_set_Bathroom  T_set_Room3  T_set_Room1  \
# 0  2021-02-15 00:00:00+00:00            17.0         17.0         17.0
# 1  2021-02-15 00:15:00+00:00            17.0         17.0         17.0
# 2  2021-02-15 00:30:00+00:00            17.0         17.0         17.0
# 3  2021-02-15 00:45:00+00:00            17.0         17.0         17.0
# 4  2021-02-15 01:00:00+00:00            17.0         17.0         17.0
#
#    T_set_Room2  T_set_Kitchen  T_set_Dining  T_set_Living  T_m_ext  T_m_water  \
# 0         17.0           16.0          16.0          16.0      1.0  34.000000
# 1         17.0           16.0          16.0          16.0      1.0  42.000000
# 2         17.0           16.0          16.0          16.0      1.0  45.666667
# 3         17.0           16.0          16.0          16.0      1.0  45.666667
# 4         17.0           16.0          16.0          16.0      1.0  38.666667
#
# ...

# %%
plot_data(data, x="Datetime", y=["T_m_Dining", "T_set_Dining"])

# %%
data["T_m_Dining"]
# Out:
# 0       18.600000
# 1       18.493745
# 2       18.398489
# 3       18.302218
# 4       18.201035
#           ...
# 1336    17.868595
# 1337    17.767464
# 1338    17.667798
# 1339    17.569528
# 1340    17.473177
# Name: T_m_Dining, Length: 1341, dtype: float64

# %%
plot_data(t_bedroom_1, x="time", y=["current_value", "setpoint"])

# %%
plot_data(t_outside, x="time", y=["current_value"])

# %%
t_bedroom_1.head()
# Out:
#                    time  current_value  setpoint
# 0  2020-05-24T19:40:03Z           22.5        16
# 1  2020-05-24T19:45:03Z           22.5        16
# 2  2020-05-24T19:50:03Z           22.4        16
# 3  2020-05-24T19:55:03Z           22.4        16
# 4  2020-05-24T20:00:04Z           22.4        16
